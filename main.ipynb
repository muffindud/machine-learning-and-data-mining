# %% [markdown]
# # Machine Learning and Data Mining

# %% [markdown]
# ## Laboratory Work No. 1: Unsupervised Learning

# %%
from sklearn.metrics import silhouette_score

# %% [markdown]
# ## Laboratory Work 2: Supervised Learning
